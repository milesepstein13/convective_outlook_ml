# %% [markdown]
# This file will train a linear regression model with the training data in data and save the model to models and model results to model_results
#
# Similar files will be made for each model

# %%
import xarray as xr

# %%
level = "small"
input_dir = "data/processed_data"
target_dir = "data/processed_data"
stats_dir = "data/processed_data"

# %%
inputs = xr.open_zarr(f"{input_dir}/train_inputs_{level}.zarr")
targets = xr.open_dataset(f"{target_dir}/train_targets.nc")
stats = xr.open_dataset(f"{stats_dir}/daily_input_stats_{level}.nc")

# %%
stats
# Out:
# <xarray.Dataset>
# Dimensions:                            (day: 332, level: 5)
# Coordinates:
#   * day                                (day) datetime64[ns] 2002-04-07 ... 20...
#   * level                              (level) int64 925 850 700 500 300
# Data variables: (12/26)
#     10m_u_component_of_wind_mean       (day) float32 ...
#     10m_u_component_of_wind_std        (day) float32 ...
#     10m_v_component_of_wind_mean       (day) float32 ...
#     10m_v_component_of_wind_std        (day) float32 ...
#     2m_dewpoint_temperature_mean       (day) float32 ...
#     2m_dewpoint_temperature_std        (day) float32 ...
#     ...                                 ...
#     u_component_of_wind_mean           (level, day) float32 ...
#     u_component_of_wind_std            (level, day) float32 ...
#     v_component_of_wind_mean           (level, day) float32 ...
#     v_component_of_wind_std            (level, day) float32 ...
#     vertical_velocity_mean             (level, day) float32 ...
#     vertical_velocity_std              (level, day) float32 ...
